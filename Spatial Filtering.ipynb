# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# %%
from helpers import *
from ip_functions import *
from spatial_filters import *

# %%
img = cv2.imread("Images/image_for_filter.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.figure(figsize = (25,25))
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
show_two_images(img, correlation_filter(img,avg_filter), title0 = "Original Image", title1 = "Original Image Filtered with average filter")

# %%
show_two_images(img, correlation_filter(img,weighted_avg_filter),title0 = "Original Image", title1 = "Original Image Filtered with weighted average filter" )

# %%
show_two_images(img, correlation_filter(img,laplacian_filter_4),title0 = "Original Image", title1 = "Original Image Filtered with Laplacian4 filter" )

# %%
show_two_images(img, correlation_filter(img,laplacian_filter_8),title0 = "Original Image", title1 = "Original Image Filtered with Laplacian8 filter" )

# %%
show_two_images(img, correlation_filter(img,sobel_horizontal_filter), title0 = "Original Image", title1 = "Original Image Filtered with horizontal sobel filter")

# %%
show_two_images(img, correlation_filter(img,sobel_vertical_filter), title0 = "Original Image", title1 = "Original Image Filtered with vertical sobel filter")

# %%
show_two_images(img, median_filter(img, 5), title0 = "Original Image", title1 = "Original Image Filtered with Median Filter of size 5")

# %%
show_two_images(img, median_filter(img, 3), title0 = "Original Image", title1 = "Original Image Filtered with Median Filter of size 3")
