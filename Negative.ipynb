# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %matplotlib inline

# %%
from helpers import *
from ip_functions import *

# %%
img = cv2.imread("Images/mri.jpg")
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.figure(figsize = (25,25))
plt.imshow(img, cmap='gray')

# %%
show_two_images(img, img_to_negative(img))

# %%
show_two_images(img, threshold_grayscale_image(img, 150), vmin1=0, vmax1=1)

# %%
show_two_images(img, zoom_by_twice(img))

# %%
show_two_images(img, mirror_image(img))

# %%
show_two_images(img, shrink_image_by_half(img))

# %%
plot_image_histogram(img)

# %%
plot_image_with_histogram(img)

# %%
show_two_images(img, stretch_contrast(img))

# %%
plot_image_with_histogram(stretch_contrast(img))

# %%
plot_image_with_histogram(histogram_equalizer(img))

# %%
plot_image_with_histogram(gamma_correction(img,0.2))

# %%
show_two_images(img, gamma_correction(img,0.4))

# %%
pixel_value = np.arange(0,256, dtype=np.int)
corrected_value = 1*np.power(pixel_value, 4)
corrected_value = corrected_value/np.max(corrected_value)
pixel_value = pixel_value/255

plt.plot(corrected_value, corrected_value)
plt.plot(pixel_value, corrected_value)
